# %%
import pandas as pd

# %%
df = pd.read_csv('../data/balanced_brightness-split-cleaned.csv')

df
# Out:
#                                              audio_path  label
# 0     AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 1     AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 2     AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 3     AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 4     AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# ...                                                 ...    ...
# 7276  HappyFamilyYogurt_Anthem_Raspberry_180110_DH_p...      9
# 7277  HappyFamilyYogurt_Anthem_Raspberry_180110_DH_p...      9
# 7278  HappyFamilyYogurt_Anthem_Raspberry_180110_DH_p...      9
# 7279  HappyFamilyYogurt_Anthem_Raspberry_180110_DH_p...      9
# 7280  HappyFamilyYogurt_Anthem_Raspberry_180110_DH_p...      9
#
# [7281 rows x 2 columns]

# %%
df.iloc[:10]
# Out:
#                                           audio_path  label
# 0  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 1  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 2  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 3  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 4  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 5  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 6  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 7  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 8  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1
# 9  AFSP_Ford_TremDaVida_Vitous_LS_150306_22h_Long...      1

# %%
df.iloc[:10].to_csv('../data/balanced_brightness-cleaned-SAMPLED.csv')
